# %% [markdown]
# <a href="https://colab.research.google.com/github/S1h2l/color-image-processing-/blob/main/convert_RGB_VS_HSV2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
""" step 1 ->  C=(0,32,128)
R=0/255=0
G=32/255=0.125
B=128/255=0.502
so C=(0,0.125,0.502) """

# %%
from skimage import io
from skimage import color
from skimage import data
from pylab import *
import numpy as np

img = io.imread("/content/OIP (2).jpg")
img_hsv = color.rgb2hsv(img)
img_rgb = color.hsv2rgb(img_hsv)
figure(0)
io.imshow(img_rgb)
figure(1)
io.imshow(img_hsv)
io.show()
# Out:
# /tmp/ipython-input-3311703264.py:11: FutureWarning: `imshow` is deprecated since version 0.25 and will be removed in version 0.27. Please use `matplotlib`, `napari`, etc. to visualize images.
#   io.imshow(img_rgb)
# /tmp/ipython-input-3311703264.py:13: FutureWarning: `imshow` is deprecated since version 0.25 and will be removed in version 0.27. Please use `matplotlib`, `napari`, etc. to visualize images.
#   io.imshow(img_hsv)
# /tmp/ipython-input-3311703264.py:14: FutureWarning: `show` is deprecated since version 0.25 and will be removed in version 0.27. Please use `matplotlib`, `napari`, etc. to visualize images.
#   io.show()
